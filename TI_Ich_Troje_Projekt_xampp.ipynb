# %% [markdown]
# # 1. Uruchomienie aplikacji XAMPP

# %% [markdown]
# -------------
# <h2>Instalacja</h2>
# <p>Instalacja pakietu xampp ze strony producenta</p>
# <p>https://www.apachefriends.org/pl/index.html</p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -------------------------
# <h2>Uruchomienie</h2>
# <p>Uruchamiamy zainstalowaną aplikację xampp</p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---------------------
# <p><b>Uruchamiamy przeglądarkę</b> - najlepiej chrome, explorer, edge</p>
# <p>Wpisujemy w adres localhost/dashboard<br>
# W zakładce <b>phpMyAdmin</b> możemy modyfikować bazę danych lub dodać nową</p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -------------------------------------------
# <h2>Przeglądanie plików projektu</h2>
# <p>Wpisujemy <b>localhost/nazwa_pliku</b></p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---------------------------------
# <h2>Uruchomienie projektu</h2>
# <p>Wpisujemy <b>localhost/nazwa_pliku/login_form.php</b>.</p>

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ----------------------------------
# ----------------------------------
# # 2. Domena online założona dzięki FileZilla
# <p>Zakładamy własną domenę na <b>https://www.prv.pl</b></p>
# <p>Po instalacji uruchamiamy FileZilla</p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ------------------------------------
# <h3>Wpisujemy adres strony</h3>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -----------------
# <h3>Przesyłamy pliki na domenę</h3>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <p>Po wpisaniu w wyszukiwarke <b>http://adres_domeny.prv.pl/register_form.php</b> przekieruje nas na stronę internetową</p>
